# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.xkcd()
x= np.linspace(10,50,10)
y = np.multiply(10,x)
x1 = np.linspace(50,90,9)
y1 = -10*x1 +1000
x2 = ([46,46,54,54])
y2 = ([100,0,0,100])
plt.scatter(x,y,color = "green")
plt.scatter(x1,y1,color = "green")
plt.plot(x2,y2,color = "brown")
plt.plot([x1[0],x[8],x1[1],x[7],x1[2],x[6],x1[3],x[5],x1[4],x[4],x1[5],x[3],x1[6],x[2],x1[7],x[1],x1[8],x[0]],
         [y1[0],y[8],y1[1],y[7],y1[2],y[6],y1[3],y[5],y1[4],y[4],y1[5],y[3],y1[6],y[2],y1[7],y[1],y1[8],y[0]],color = "green")
plt.plot(50,560,marker = "*",color = "yellow",markersize = 30)
