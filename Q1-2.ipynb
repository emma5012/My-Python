# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageFilter

im = Image.open(r'C:\Users\admin\Desktop\sg.jpg', mode='r')
newim = im.filter(ImageFilter.CONTOUR)
plt.imshow(newim);
